# %% [markdown]
# # 1.1 OBJECTIVE

# %% [markdown]
# Taking two model MobileNetV2 and ResNet50 and using CIFAR10 Dataset

# %% [markdown]
# # 1.2 EXPLORE AND COMPARE MODELS

# %% [markdown]
# | **Feature**                   | **Model 1: MobileNetV2** | **Model 2: ResNet50**          |
# |--------------------------------|--------------------------|---------------------------------|
# | **Input Image Size**          | 224×224×3               | 224×224×3                      |
# | **Parameters**                | ~3.5 million            | ~25.6 million                  |
# | **Layers / Depth**            | ~53 layers              | 50 layers                      |
# | **ImageNet Accuracy (Top-1)** | ~71.8%                  | ~76.0%                         |
# | **Model Size (MB)**           | ~14 MB                  | ~98 MB                         |
# | **Inference Speed (CPU)**     | ~75 ms per image        | ~100–120 ms per image          |

# %% [markdown]
# # 1.3  PICK A TOY DATASET

# %%
import tensorflow
print(tensorflow)
# Out:
# 2025-07-04 19:28:33.838413: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751639313.854640     919 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751639313.859470     919 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1751639313.870486     919 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751639313.870504     919 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751639313.870506     919 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751639313.870508     919 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-04 19:28:33.874418: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <module 'tensorflow' from '/home/moon/tf-gpu-venv/lib/python3.12/site-packages/tensorflow/__init__.py'>

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.19.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

# %% [markdown]
# # 1.4 TRANSFER LEARNING WORKFLOW

# %% [markdown]
# ##   1. Load & preprocess the dataset

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Load the dataset
(ds_train_full, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

print(ds_info)
# Out:
# I0000 00:00:1751639317.921530     919 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6096 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070, pci bus id: 0000:08:00.0, compute capability: 7.5
# tfds.core.DatasetInfo(
#     name='cifar10',
#     full_name='cifar10/3.0.2',
#     description="""
#     The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#     """,
#     homepage='https://www.cs.toronto.edu/~kriz/cifar.html',
#     data_dir='/home/moon/tensorflow_datasets/cifar10/3.0.2',
#     file_format=tfrecord,
#     download_size=162.17 MiB,
#     dataset_size=132.40 MiB,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=string),
#         'image': Image(shape=(32, 32, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     nondeterministic_order=False,
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=50000, num_shards=1>,
#     },
#     citation="""@TECHREPORT{Krizhevsky09learningmultiple,
#         author = {Alex Krizhevsky},
#         title = {Learning multiple layers of features from tiny images},
#         institution = {},
#         year = {2009}
#     }""",
# )

# %%
# Constants
BATCH_SIZE = 64
IMG_SIZE = (128, 128)

# Split train into train + validation
# e.g., 80% train, 20% validation
train_size = 0.8
train_count = int(ds_info.splits['train'].num_examples * train_size)

ds_train = ds_train_full.take(train_count)
ds_val = ds_train_full.skip(train_count)

# Preprocessing function
def preprocess(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

# Prepare train dataset
train_dataset = (
    ds_train
    .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(1000)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# Prepare validation dataset
validation_dataset = (
    ds_val
    .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# Prepare test dataset
test_dataset = (
    ds_test
    .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
# Inspect one batch
for images, labels in train_dataset.take(1):
    print(f"Images shape: {images.shape}")
    print(f"Labels shape: {labels.shape}")
    print(f"Labels: {labels.numpy()}")
# Out:
# 2025-07-04 19:28:38.635523: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# Images shape: (64, 128, 128, 3)
# Labels shape: (64,)
# Labels: [8 2 5 6 2 8 7 9 6 5 2 0 2 7 0 8 9 8 7 3 7 5 1 5 9 0 0 7 2 9 0 9 9 6 9 5 8
#  4 4 2 5 5 9 7 0 7 1 3 3 4 9 0 6 0 8 5 3 0 9 6 0 4 8 8]
# 2025-07-04 19:28:38.922828: W tensorflow/core/kernels/data/cache_dataset_ops.cc:916] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2025-07-04 19:28:38.925788: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
class_names = ds_info.features['label'].names
print(class_names)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow((images[i].numpy() * 255).astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# 2025-07-04 19:28:39.253201: W tensorflow/core/kernels/data/cache_dataset_ops.cc:916] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2025-07-04 19:28:39.353147: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(4* val_batches // 5)
validation_dataset = validation_dataset.skip(4* val_batches // 5)

# %%
print('Number of train batches: %d' % tf.data.experimental.cardinality(train_dataset))
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of train batches: 625
# Number of validation batches: 32
# Number of test batches: 125

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ##   2. Load the pretrained model

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
base_model_resnet = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
preprocess_input_resnet = tf.keras.applications.resnet50.preprocess_input

# %%
base_model.trainable = False

# %%
base_model_resnet.trainable = False

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_128"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 64, 64,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 64, 64,    │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 64, 64,    │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 64, 64,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 65, 65,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 32, 32,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 32, 32,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 32, 32,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 32, 32,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 32, 32,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 32, 32,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 32, 32,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 32, 32,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 32, 32,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 32, 32,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 32, 32,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 32, 32,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 32, 32,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 33, 33,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 16, 16,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 16, 16,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 16, 16,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 16, 16,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 16, 16,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 16, 16,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 16, 16,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 16, 16,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 16, 16,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 16, 16,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 16, 16,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 16, 16,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 16, 16,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 16, 16,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 16, 16,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 16, 16,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 16, 16,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 16, 16,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 16, 16,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 16, 16,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 17, 17,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 8, 8, 192) │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 8, 8, 64)  │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 8, 8, 64)  │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 8, 8, 384) │     24,576 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 8, 8, 384) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 8, 8, 64)  │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 8, 8, 64)  │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 8, 8, 384) │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 8, 8, 384) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 8, 8, 64)  │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 8, 8, 64)  │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 8, 8, 384) │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 8, 8, 384) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 8, 8, 64)  │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 8, 8, 64)  │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 8, 8, 384) │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 8, 8, 384) │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 8, 8, 384) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 8, 8, 384) │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 8, 8, 96)  │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 8, 8, 96)  │        384 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 8, 8, 576) │     55,296 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 8, 8, 576) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 8, 8, 96)  │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 8, 8, 96)  │        384 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 8, 8, 576) │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 8, 8, 576) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 8, 8, 96)  │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 8, 8, 96)  │        384 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 8, 8, 576) │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 8, 8, 576) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 9, 9, 576) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 4, 4, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 4, 4, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 4, 4, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 4, 4, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 4, 4, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 4, 4, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 4, 4, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 4, 4, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 4, 4, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 4, 4, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 4, 4, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 4, 4, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 4, 4, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 4, 4, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 4, 4, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 4, 4, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 4, 4, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 4, 4,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 4, 4,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 4, 4,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
base_model_resnet.summary()
# Out:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 134, 134,  │          0 │ input_layer_3[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 64, 64,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 64, 64,    │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 64, 64,    │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 66, 66,    │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 32, 32,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 32, 32,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 32, 32,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 32, 32,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 32, 32,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 32, 32,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 32, 32,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 32, 32,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 32, 32,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 32, 32,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 32, 32,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 32, 32,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 32, 32,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 32, 32,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 32, 32,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 32, 32,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 32, 32,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 32, 32,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 32, 32,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 32, 32,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 32, 32,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 32, 32,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 32, 32,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 32, 32,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 16, 16,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 16, 16,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 16, 16,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 16, 16,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 16, 16,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 16, 16,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 16, 16,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 16, 16,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 16, 16,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 16, 16,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 16, 16,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 16, 16,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 16, 16,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 16, 16,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 16, 16,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 16, 16,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 16, 16,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 16, 16,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 16, 16,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 16, 16,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 16, 16,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 16, 16,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 16, 16,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 16, 16,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 16, 16,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 16, 16,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 16, 16,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 8, 8, 256) │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 8, 8,      │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 8, 8,      │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 8, 8,      │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 8, 8,      │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 8, 8,      │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 8, 8,      │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 8, 8,      │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 8, 8,      │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 8, 8,      │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 8, 8,      │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 8, 8,      │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 8, 8,      │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 8, 8,      │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 8, 8,      │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 4, 4, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 4, 4,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 4, 4,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 4, 4,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 4, 4,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 4, 4, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 4, 4,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 4, 4,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 4, 4, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 4, 4,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 4, 4,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# pip list | findstr tensorflow

# %%
image_batch, label_batch = next(iter(train_dataset))
print("Batch shapes:", image_batch.shape, label_batch.shape)
# Out:
# Batch shapes: (64, 128, 128, 3) (64,)
# 2025-07-04 19:28:45.027967: W tensorflow/core/kernels/data/cache_dataset_ops.cc:916] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
print("Dtype:", image_batch.dtype)
print("Min value:", tf.reduce_min(image_batch).numpy())
print("Max value:", tf.reduce_max(image_batch).numpy())
# Out:
# Dtype: <dtype: 'float32'>
# Min value: 0.0
# Max value: 1.0

# %%
# image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# I0000 00:00:1751639325.110448     919 cuda_dnn.cc:529] Loaded cuDNN version 90300
# (64, 4, 4, 1280)

# %%
feature_batch_resnet = base_model_resnet(image_batch)
print(feature_batch_resnet.shape)
# Out:
# (64, 4, 4, 2048)

# %% [markdown]
# ##   3. Add custom classifier head

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (64, 1280)

# %%
global_average_layer_resnet = tf.keras.layers.GlobalAveragePooling2D()

feature_batch_average_resnet = global_average_layer(feature_batch_resnet)
print(feature_batch_average_resnet.shape)
# Out:
# (64, 2048)

# %%
prediction_layer = tf.keras.layers.Dense(10, activation='softmax')

prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (64, 10)

# %%
prediction_layer_resnet = tf.keras.layers.Dense(10, activation='softmax')

prediction_batch_resnet = prediction_layer_resnet(feature_batch_average_resnet)
print(prediction_batch_resnet.shape)
# Out:
# (64, 10)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
])

# %%
dropout_layer = tf.keras.layers.Dropout(0.2)

# %%
inputs = tf.keras.Input(shape=(IMG_SIZE[0],IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = dropout_layer(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
inputs = tf.keras.Input(shape=(IMG_SIZE[0],IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = preprocess_input_resnet(x)
x = base_model_resnet(x, training=False)
x = global_average_layer_resnet(x)
x = dropout_layer(x)
outputs = prediction_layer_resnet(x)
model_resnet = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_128            │ (None, 4, 4, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        12,810 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,270,794 (8.66 MB)
#  Trainable params: 12,810 (50.04 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model_resnet.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 128, 128,  │          0 │ input_layer_5[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 128, 128)  │          0 │ sequential[2][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_4          │ (None, 128, 128)  │          0 │ sequential[2][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_5          │ (None, 128, 128)  │          0 │ sequential[2][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_1 (Stack)     │ (None, 128, 128,  │          0 │ get_item_3[0][0], │
# │                     │ 3)                │            │ get_item_4[0][0], │
# │                     │                   │            │ get_item_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 128,  │          0 │ stack_1[0][0]     │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 4, 4,      │ 23,587,712 │ add_1[0][0]       │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[1][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 10)        │     20,490 │ dropout[2][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,608,202 (90.06 MB)
#  Trainable params: 20,490 (80.04 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
len(model.trainable_variables)
# Out:
# 2

# %% [markdown]
# ## 4.Train the model

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=["accuracy"])

# %%
base_learning_rate = 0.0001
model_resnet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=["accuracy"])

# %%
loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.1049 - loss: 2.5558

# %%
loss0, accuracy0 = model_resnet.evaluate(validation_dataset)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.0993 - loss: 2.7049

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                 factor=0.5,
                                                 patience=3,
                                                 min_lr=1e-6,
                                                 verbose=1)
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_tuned_model.keras',
                                                monitor='val_loss',
                                                save_best_only=True,
                                                verbose=1)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                              patience=10,
                                              restore_best_weights=True,
                                              verbose=1)

# %%
initial_epochs = 100


history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset,
                    callbacks=[reduce_lr, checkpoint, early_stop])
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.0990 - loss: 2.4484
# Epoch 1: val_loss improved from inf to 2.30466, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 96ms/step - accuracy: 0.0990 - loss: 2.4483 - val_accuracy: 0.1015 - val_loss: 2.3047 - learning_rate: 1.0000e-04
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1015 - loss: 2.3991
# Epoch 2: val_loss improved from 2.30466 to 2.29177, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.1015 - loss: 2.3991 - val_accuracy: 0.1070 - val_loss: 2.2918 - learning_rate: 1.0000e-04
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1019 - loss: 2.3742
# Epoch 3: val_loss improved from 2.29177 to 2.28507, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.1019 - loss: 2.3742 - val_accuracy: 0.1170 - val_loss: 2.2851 - learning_rate: 1.0000e-04
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1060 - loss: 2.3560
# Epoch 4: val_loss improved from 2.28507 to 2.27654, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.1060 - loss: 2.3560 - val_accuracy: 0.2040 - val_loss: 2.2765 - learning_rate: 1.0000e-04
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1152 - loss: 2.3343
# Epoch 5: val_loss improved from 2.27654 to 2.27021, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.1152 - loss: 2.3343 - val_accuracy: 0.2010 - val_loss: 2.2702 - learning_rate: 1.0000e-04
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1200 - loss: 2.3198
# Epoch 6: val_loss improved from 2.27021 to 2.26680, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 97ms/step - accuracy: 0.1200 - loss: 2.3198 - val_accuracy: 0.1995 - val_loss: 2.2668 - learning_rate: 1.0000e-04
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1186 - loss: 2.3098
# Epoch 7: val_loss improved from 2.26680 to 2.25819, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 97ms/step - accuracy: 0.1186 - loss: 2.3098 - val_accuracy: 0.2295 - val_loss: 2.2582 - learning_rate: 1.0000e-04
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1284 - loss: 2.2971
# Epoch 8: val_loss improved from 2.25819 to 2.25056, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 97ms/step - accuracy: 0.1284 - loss: 2.2971 - val_accuracy: 0.2075 - val_loss: 2.2506 - learning_rate: 1.0000e-04
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1351 - loss: 2.2895
# Epoch 9: val_loss improved from 2.25056 to 2.24782, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 97ms/step - accuracy: 0.1351 - loss: 2.2895 - val_accuracy: 0.2190 - val_loss: 2.2478 - learning_rate: 1.0000e-04
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.1335 - loss: 2.2830
# Epoch 10: val_loss improved from 2.24782 to 2.24123, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 97ms/step - accuracy: 0.1335 - loss: 2.2830 - val_accuracy: 0.1990 - val_loss: 2.2412 - learning_rate: 1.0000e-04
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1428 - loss: 2.2759
# Epoch 11: val_loss improved from 2.24123 to 2.23570, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 97ms/step - accuracy: 0.1428 - loss: 2.2759 - val_accuracy: 0.2025 - val_loss: 2.2357 - learning_rate: 1.0000e-04
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1402 - loss: 2.2721
# Epoch 12: val_loss improved from 2.23570 to 2.23121, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 97ms/step - accuracy: 0.1402 - loss: 2.2720 - val_accuracy: 0.2240 - val_loss: 2.2312 - learning_rate: 1.0000e-04
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1495 - loss: 2.2622
# Epoch 13: val_loss improved from 2.23121 to 2.22677, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 98ms/step - accuracy: 0.1495 - loss: 2.2622 - val_accuracy: 0.2405 - val_loss: 2.2268 - learning_rate: 1.0000e-04
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1475 - loss: 2.2595
# Epoch 14: val_loss improved from 2.22677 to 2.22439, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1475 - loss: 2.2595 - val_accuracy: 0.2345 - val_loss: 2.2244 - learning_rate: 1.0000e-04
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1601 - loss: 2.2500
# Epoch 15: val_loss improved from 2.22439 to 2.22106, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1601 - loss: 2.2500 - val_accuracy: 0.2140 - val_loss: 2.2211 - learning_rate: 1.0000e-04
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1624 - loss: 2.2470
# Epoch 16: val_loss improved from 2.22106 to 2.21228, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1624 - loss: 2.2470 - val_accuracy: 0.2520 - val_loss: 2.2123 - learning_rate: 1.0000e-04
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1554 - loss: 2.2482
# Epoch 17: val_loss improved from 2.21228 to 2.20958, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1554 - loss: 2.2482 - val_accuracy: 0.2400 - val_loss: 2.2096 - learning_rate: 1.0000e-04
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1644 - loss: 2.2415
# Epoch 18: val_loss improved from 2.20958 to 2.20653, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1644 - loss: 2.2415 - val_accuracy: 0.2340 - val_loss: 2.2065 - learning_rate: 1.0000e-04
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1689 - loss: 2.2388
# Epoch 19: val_loss improved from 2.20653 to 2.20162, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1689 - loss: 2.2388 - val_accuracy: 0.2590 - val_loss: 2.2016 - learning_rate: 1.0000e-04
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1655 - loss: 2.2360
# Epoch 20: val_loss improved from 2.20162 to 2.19631, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 98ms/step - accuracy: 0.1655 - loss: 2.2360 - val_accuracy: 0.2720 - val_loss: 2.1963 - learning_rate: 1.0000e-04
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1755 - loss: 2.2300
# Epoch 21: val_loss improved from 2.19631 to 2.19421, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1755 - loss: 2.2300 - val_accuracy: 0.2440 - val_loss: 2.1942 - learning_rate: 1.0000e-04
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1743 - loss: 2.2284
# Epoch 22: val_loss improved from 2.19421 to 2.19118, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 98ms/step - accuracy: 0.1743 - loss: 2.2283 - val_accuracy: 0.2520 - val_loss: 2.1912 - learning_rate: 1.0000e-04
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1741 - loss: 2.2256
# Epoch 23: val_loss improved from 2.19118 to 2.18799, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1741 - loss: 2.2256 - val_accuracy: 0.2400 - val_loss: 2.1880 - learning_rate: 1.0000e-04
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1770 - loss: 2.2214
# Epoch 24: val_loss improved from 2.18799 to 2.18170, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1770 - loss: 2.2214 - val_accuracy: 0.2645 - val_loss: 2.1817 - learning_rate: 1.0000e-04
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1773 - loss: 2.2212
# Epoch 25: val_loss improved from 2.18170 to 2.17929, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - accuracy: 0.1773 - loss: 2.2212 - val_accuracy: 0.2620 - val_loss: 2.1793 - learning_rate: 1.0000e-04
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1771 - loss: 2.2204
# Epoch 26: val_loss improved from 2.17929 to 2.17635, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - accuracy: 0.1771 - loss: 2.2204 - val_accuracy: 0.2575 - val_loss: 2.1763 - learning_rate: 1.0000e-04
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1839 - loss: 2.2150
# Epoch 27: val_loss improved from 2.17635 to 2.17325, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - accuracy: 0.1839 - loss: 2.2150 - val_accuracy: 0.2690 - val_loss: 2.1733 - learning_rate: 1.0000e-04
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1877 - loss: 2.2142
# Epoch 28: val_loss improved from 2.17325 to 2.17133, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - accuracy: 0.1877 - loss: 2.2142 - val_accuracy: 0.2530 - val_loss: 2.1713 - learning_rate: 1.0000e-04
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1860 - loss: 2.2099
# Epoch 29: val_loss improved from 2.17133 to 2.16966, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - accuracy: 0.1860 - loss: 2.2099 - val_accuracy: 0.2510 - val_loss: 2.1697 - learning_rate: 1.0000e-04
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1920 - loss: 2.2058
# Epoch 30: val_loss improved from 2.16966 to 2.16413, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 61s 98ms/step - accuracy: 0.1920 - loss: 2.2057 - val_accuracy: 0.2800 - val_loss: 2.1641 - learning_rate: 1.0000e-04
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1901 - loss: 2.2071
# Epoch 31: val_loss improved from 2.16413 to 2.16205, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1901 - loss: 2.2071 - val_accuracy: 0.2840 - val_loss: 2.1621 - learning_rate: 1.0000e-04
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1915 - loss: 2.2049
# Epoch 32: val_loss improved from 2.16205 to 2.15939, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - accuracy: 0.1915 - loss: 2.2049 - val_accuracy: 0.2805 - val_loss: 2.1594 - learning_rate: 1.0000e-04
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1945 - loss: 2.2008
# Epoch 33: val_loss improved from 2.15939 to 2.15820, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1945 - loss: 2.2008 - val_accuracy: 0.2820 - val_loss: 2.1582 - learning_rate: 1.0000e-04
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1941 - loss: 2.2011
# Epoch 34: val_loss improved from 2.15820 to 2.15545, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1941 - loss: 2.2011 - val_accuracy: 0.2840 - val_loss: 2.1554 - learning_rate: 1.0000e-04
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1942 - loss: 2.2000
# Epoch 35: val_loss improved from 2.15545 to 2.15105, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1942 - loss: 2.2000 - val_accuracy: 0.2810 - val_loss: 2.1510 - learning_rate: 1.0000e-04
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1966 - loss: 2.1987
# Epoch 36: val_loss improved from 2.15105 to 2.15043, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - accuracy: 0.1966 - loss: 2.1987 - val_accuracy: 0.2645 - val_loss: 2.1504 - learning_rate: 1.0000e-04
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2005 - loss: 2.1956
# Epoch 37: val_loss did not improve from 2.15043
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.2005 - loss: 2.1956 - val_accuracy: 0.2735 - val_loss: 2.1514 - learning_rate: 1.0000e-04
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1907 - loss: 2.1958
# Epoch 38: val_loss improved from 2.15043 to 2.14841, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1907 - loss: 2.1958 - val_accuracy: 0.2725 - val_loss: 2.1484 - learning_rate: 1.0000e-04
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1969 - loss: 2.1939
# Epoch 39: val_loss improved from 2.14841 to 2.14147, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1969 - loss: 2.1939 - val_accuracy: 0.2830 - val_loss: 2.1415 - learning_rate: 1.0000e-04
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1926 - loss: 2.1922
# Epoch 40: val_loss did not improve from 2.14147
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1926 - loss: 2.1922 - val_accuracy: 0.2795 - val_loss: 2.1443 - learning_rate: 1.0000e-04
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1996 - loss: 2.1918
# Epoch 41: val_loss improved from 2.14147 to 2.13868, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - accuracy: 0.1997 - loss: 2.1918 - val_accuracy: 0.2690 - val_loss: 2.1387 - learning_rate: 1.0000e-04
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.1995 - loss: 2.1860
# Epoch 42: val_loss improved from 2.13868 to 2.13499, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.1995 - loss: 2.1860 - val_accuracy: 0.2730 - val_loss: 2.1350 - learning_rate: 1.0000e-04
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2026 - loss: 2.1880
# Epoch 43: val_loss did not improve from 2.13499
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2026 - loss: 2.1880 - val_accuracy: 0.2725 - val_loss: 2.1352 - learning_rate: 1.0000e-04
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.1979 - loss: 2.1890
# Epoch 44: val_loss improved from 2.13499 to 2.13132, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.1979 - loss: 2.1890 - val_accuracy: 0.2905 - val_loss: 2.1313 - learning_rate: 1.0000e-04
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2015 - loss: 2.1836
# Epoch 45: val_loss did not improve from 2.13132
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2015 - loss: 2.1836 - val_accuracy: 0.2720 - val_loss: 2.1313 - learning_rate: 1.0000e-04
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2024 - loss: 2.1813
# Epoch 46: val_loss improved from 2.13132 to 2.12932, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - accuracy: 0.2024 - loss: 2.1813 - val_accuracy: 0.2695 - val_loss: 2.1293 - learning_rate: 1.0000e-04
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2057 - loss: 2.1810
# Epoch 47: val_loss improved from 2.12932 to 2.12843, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2057 - loss: 2.1810 - val_accuracy: 0.2750 - val_loss: 2.1284 - learning_rate: 1.0000e-04
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2066 - loss: 2.1795
# Epoch 48: val_loss improved from 2.12843 to 2.12335, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2066 - loss: 2.1795 - val_accuracy: 0.2965 - val_loss: 2.1233 - learning_rate: 1.0000e-04
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.2043 - loss: 2.1804
# Epoch 49: val_loss improved from 2.12335 to 2.12044, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - accuracy: 0.2043 - loss: 2.1804 - val_accuracy: 0.2910 - val_loss: 2.1204 - learning_rate: 1.0000e-04
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2071 - loss: 2.1795
# Epoch 50: val_loss did not improve from 2.12044
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - accuracy: 0.2071 - loss: 2.1795 - val_accuracy: 0.2795 - val_loss: 2.1214 - learning_rate: 1.0000e-04
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2070 - loss: 2.1763
# Epoch 51: val_loss improved from 2.12044 to 2.11804, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.2070 - loss: 2.1763 - val_accuracy: 0.2845 - val_loss: 2.1180 - learning_rate: 1.0000e-04
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.2081 - loss: 2.1753
# Epoch 52: val_loss improved from 2.11804 to 2.11618, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 68s 109ms/step - accuracy: 0.2081 - loss: 2.1753 - val_accuracy: 0.2665 - val_loss: 2.1162 - learning_rate: 1.0000e-04
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2057 - loss: 2.1735
# Epoch 53: val_loss improved from 2.11618 to 2.11491, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2057 - loss: 2.1735 - val_accuracy: 0.2790 - val_loss: 2.1149 - learning_rate: 1.0000e-04
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2064 - loss: 2.1724
# Epoch 54: val_loss improved from 2.11491 to 2.11196, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2064 - loss: 2.1724 - val_accuracy: 0.2900 - val_loss: 2.1120 - learning_rate: 1.0000e-04
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2088 - loss: 2.1715
# Epoch 55: val_loss improved from 2.11196 to 2.11173, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2088 - loss: 2.1715 - val_accuracy: 0.2905 - val_loss: 2.1117 - learning_rate: 1.0000e-04
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2028 - loss: 2.1740
# Epoch 56: val_loss did not improve from 2.11173
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2028 - loss: 2.1740 - val_accuracy: 0.2810 - val_loss: 2.1135 - learning_rate: 1.0000e-04
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2117 - loss: 2.1708
# Epoch 57: val_loss improved from 2.11173 to 2.10987, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2117 - loss: 2.1708 - val_accuracy: 0.2725 - val_loss: 2.1099 - learning_rate: 1.0000e-04
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2096 - loss: 2.1688
# Epoch 58: val_loss improved from 2.10987 to 2.10836, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2096 - loss: 2.1688 - val_accuracy: 0.2900 - val_loss: 2.1084 - learning_rate: 1.0000e-04
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2116 - loss: 2.1678
# Epoch 59: val_loss improved from 2.10836 to 2.10706, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - accuracy: 0.2116 - loss: 2.1678 - val_accuracy: 0.2875 - val_loss: 2.1071 - learning_rate: 1.0000e-04
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2110 - loss: 2.1661
# Epoch 60: val_loss improved from 2.10706 to 2.10309, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2110 - loss: 2.1661 - val_accuracy: 0.3025 - val_loss: 2.1031 - learning_rate: 1.0000e-04
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2099 - loss: 2.1679
# Epoch 61: val_loss improved from 2.10309 to 2.10278, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - accuracy: 0.2099 - loss: 2.1679 - val_accuracy: 0.2800 - val_loss: 2.1028 - learning_rate: 1.0000e-04
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2073 - loss: 2.1645
# Epoch 62: val_loss improved from 2.10278 to 2.10052, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - accuracy: 0.2073 - loss: 2.1645 - val_accuracy: 0.2915 - val_loss: 2.1005 - learning_rate: 1.0000e-04
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2106 - loss: 2.1668
# Epoch 63: val_loss did not improve from 2.10052
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2106 - loss: 2.1668 - val_accuracy: 0.2835 - val_loss: 2.1008 - learning_rate: 1.0000e-04
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2127 - loss: 2.1653
# Epoch 64: val_loss improved from 2.10052 to 2.09704, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - accuracy: 0.2127 - loss: 2.1653 - val_accuracy: 0.2925 - val_loss: 2.0970 - learning_rate: 1.0000e-04
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2071 - loss: 2.1630
# Epoch 65: val_loss improved from 2.09704 to 2.09499, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2072 - loss: 2.1630 - val_accuracy: 0.2990 - val_loss: 2.0950 - learning_rate: 1.0000e-04
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2109 - loss: 2.1596
# Epoch 66: val_loss did not improve from 2.09499
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - accuracy: 0.2109 - loss: 2.1596 - val_accuracy: 0.2850 - val_loss: 2.0952 - learning_rate: 1.0000e-04
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2142 - loss: 2.1620
# Epoch 67: val_loss improved from 2.09499 to 2.09450, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - accuracy: 0.2142 - loss: 2.1620 - val_accuracy: 0.2935 - val_loss: 2.0945 - learning_rate: 1.0000e-04
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2110 - loss: 2.1643
# Epoch 68: val_loss improved from 2.09450 to 2.09194, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2110 - loss: 2.1643 - val_accuracy: 0.2925 - val_loss: 2.0919 - learning_rate: 1.0000e-04
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2102 - loss: 2.1614
# Epoch 69: val_loss improved from 2.09194 to 2.09014, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2102 - loss: 2.1614 - val_accuracy: 0.2905 - val_loss: 2.0901 - learning_rate: 1.0000e-04
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2140 - loss: 2.1599
# Epoch 70: val_loss improved from 2.09014 to 2.08795, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2140 - loss: 2.1599 - val_accuracy: 0.2955 - val_loss: 2.0879 - learning_rate: 1.0000e-04
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2172 - loss: 2.1574
# Epoch 71: val_loss did not improve from 2.08795
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2172 - loss: 2.1574 - val_accuracy: 0.2885 - val_loss: 2.0887 - learning_rate: 1.0000e-04
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2152 - loss: 2.1592
# Epoch 72: val_loss did not improve from 2.08795
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2152 - loss: 2.1592 - val_accuracy: 0.2870 - val_loss: 2.0899 - learning_rate: 1.0000e-04
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2182 - loss: 2.1587
# Epoch 73: val_loss improved from 2.08795 to 2.08675, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2182 - loss: 2.1587 - val_accuracy: 0.2970 - val_loss: 2.0868 - learning_rate: 1.0000e-04
# Epoch 74/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2144 - loss: 2.1575
# Epoch 74: val_loss improved from 2.08675 to 2.08332, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.2144 - loss: 2.1575 - val_accuracy: 0.2930 - val_loss: 2.0833 - learning_rate: 1.0000e-04
# Epoch 75/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2189 - loss: 2.1550
# Epoch 75: val_loss did not improve from 2.08332
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.2189 - loss: 2.1550 - val_accuracy: 0.2920 - val_loss: 2.0836 - learning_rate: 1.0000e-04
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2175 - loss: 2.1551
# Epoch 76: val_loss did not improve from 2.08332
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - accuracy: 0.2175 - loss: 2.1551 - val_accuracy: 0.2890 - val_loss: 2.0847 - learning_rate: 1.0000e-04
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2151 - loss: 2.1539
# Epoch 77: val_loss improved from 2.08332 to 2.08134, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2151 - loss: 2.1539 - val_accuracy: 0.2905 - val_loss: 2.0813 - learning_rate: 1.0000e-04
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2165 - loss: 2.1561
# Epoch 78: val_loss did not improve from 2.08134
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - accuracy: 0.2165 - loss: 2.1561 - val_accuracy: 0.2955 - val_loss: 2.0819 - learning_rate: 1.0000e-04
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2160 - loss: 2.1519
# Epoch 79: val_loss improved from 2.08134 to 2.08009, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.2161 - loss: 2.1519 - val_accuracy: 0.2915 - val_loss: 2.0801 - learning_rate: 1.0000e-04
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2205 - loss: 2.1484
# Epoch 80: val_loss improved from 2.08009 to 2.07713, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.2205 - loss: 2.1484 - val_accuracy: 0.2985 - val_loss: 2.0771 - learning_rate: 1.0000e-04
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2176 - loss: 2.1526
# Epoch 81: val_loss did not improve from 2.07713
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2176 - loss: 2.1526 - val_accuracy: 0.2890 - val_loss: 2.0788 - learning_rate: 1.0000e-04
# Epoch 82/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2223 - loss: 2.1497
# Epoch 82: val_loss improved from 2.07713 to 2.07537, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2223 - loss: 2.1497 - val_accuracy: 0.3140 - val_loss: 2.0754 - learning_rate: 1.0000e-04
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2214 - loss: 2.1495
# Epoch 83: val_loss did not improve from 2.07537
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2214 - loss: 2.1495 - val_accuracy: 0.2980 - val_loss: 2.0755 - learning_rate: 1.0000e-04
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2124 - loss: 2.1493
# Epoch 84: val_loss improved from 2.07537 to 2.07401, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2124 - loss: 2.1493 - val_accuracy: 0.2955 - val_loss: 2.0740 - learning_rate: 1.0000e-04
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.2153 - loss: 2.1504
# Epoch 85: val_loss improved from 2.07401 to 2.07225, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 68s 108ms/step - accuracy: 0.2153 - loss: 2.1504 - val_accuracy: 0.2900 - val_loss: 2.0723 - learning_rate: 1.0000e-04
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2171 - loss: 2.1496
# Epoch 86: val_loss improved from 2.07225 to 2.07194, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.2171 - loss: 2.1496 - val_accuracy: 0.2930 - val_loss: 2.0719 - learning_rate: 1.0000e-04
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2155 - loss: 2.1490
# Epoch 87: val_loss improved from 2.07194 to 2.06884, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2155 - loss: 2.1490 - val_accuracy: 0.2895 - val_loss: 2.0688 - learning_rate: 1.0000e-04
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2215 - loss: 2.1440
# Epoch 88: val_loss did not improve from 2.06884
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2215 - loss: 2.1440 - val_accuracy: 0.2805 - val_loss: 2.0725 - learning_rate: 1.0000e-04
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.2164 - loss: 2.1456
# Epoch 89: val_loss did not improve from 2.06884
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.2164 - loss: 2.1456 - val_accuracy: 0.2895 - val_loss: 2.0707 - learning_rate: 1.0000e-04
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2234 - loss: 2.1442
# Epoch 90: val_loss improved from 2.06884 to 2.06619, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - accuracy: 0.2234 - loss: 2.1442 - val_accuracy: 0.3040 - val_loss: 2.0662 - learning_rate: 1.0000e-04
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2219 - loss: 2.1435
# Epoch 91: val_loss did not improve from 2.06619
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.2219 - loss: 2.1435 - val_accuracy: 0.2960 - val_loss: 2.0678 - learning_rate: 1.0000e-04
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2222 - loss: 2.1443
# Epoch 92: val_loss improved from 2.06619 to 2.06538, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - accuracy: 0.2222 - loss: 2.1443 - val_accuracy: 0.2960 - val_loss: 2.0654 - learning_rate: 1.0000e-04
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2244 - loss: 2.1409
# Epoch 93: val_loss improved from 2.06538 to 2.06379, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - accuracy: 0.2244 - loss: 2.1409 - val_accuracy: 0.3015 - val_loss: 2.0638 - learning_rate: 1.0000e-04
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2234 - loss: 2.1427
# Epoch 94: val_loss did not improve from 2.06379
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2234 - loss: 2.1427 - val_accuracy: 0.2940 - val_loss: 2.0664 - learning_rate: 1.0000e-04
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2273 - loss: 2.1393
# Epoch 95: val_loss improved from 2.06379 to 2.06378, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2273 - loss: 2.1393 - val_accuracy: 0.3070 - val_loss: 2.0638 - learning_rate: 1.0000e-04
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2234 - loss: 2.1398
# Epoch 96: val_loss improved from 2.06378 to 2.06228, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2234 - loss: 2.1398 - val_accuracy: 0.2950 - val_loss: 2.0623 - learning_rate: 1.0000e-04
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2201 - loss: 2.1419
# Epoch 97: val_loss improved from 2.06228 to 2.06020, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2201 - loss: 2.1419 - val_accuracy: 0.3080 - val_loss: 2.0602 - learning_rate: 1.0000e-04
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2229 - loss: 2.1401
# Epoch 98: val_loss improved from 2.06020 to 2.05962, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - accuracy: 0.2229 - loss: 2.1401 - val_accuracy: 0.3065 - val_loss: 2.0596 - learning_rate: 1.0000e-04
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2205 - loss: 2.1402
# Epoch 99: val_loss improved from 2.05962 to 2.05849, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - accuracy: 0.2205 - loss: 2.1402 - val_accuracy: 0.3030 - val_loss: 2.0585 - learning_rate: 1.0000e-04
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2245 - loss: 2.1390
# Epoch 100: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - accuracy: 0.2245 - loss: 2.1390 - val_accuracy: 0.2835 - val_loss: 2.0607 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 99.

# %%
initial_epochs = 100


history_resnet = model_resnet.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset,
                    callbacks=[reduce_lr, checkpoint, early_stop])
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.1038 - loss: 2.4623
# Epoch 1: val_loss improved from inf to 2.29793, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - accuracy: 0.1038 - loss: 2.4622 - val_accuracy: 0.1100 - val_loss: 2.2979 - learning_rate: 1.0000e-04
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1063 - loss: 2.3266
# Epoch 2: val_loss improved from 2.29793 to 2.29142, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 121ms/step - accuracy: 0.1063 - loss: 2.3266 - val_accuracy: 0.1340 - val_loss: 2.2914 - learning_rate: 1.0000e-04
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1155 - loss: 2.3080
# Epoch 3: val_loss improved from 2.29142 to 2.28516, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 120ms/step - accuracy: 0.1155 - loss: 2.3080 - val_accuracy: 0.1650 - val_loss: 2.2852 - learning_rate: 1.0000e-04
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1194 - loss: 2.2951
# Epoch 4: val_loss improved from 2.28516 to 2.27936, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 121ms/step - accuracy: 0.1194 - loss: 2.2951 - val_accuracy: 0.1490 - val_loss: 2.2794 - learning_rate: 1.0000e-04
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1307 - loss: 2.2850
# Epoch 5: val_loss improved from 2.27936 to 2.27433, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 121ms/step - accuracy: 0.1307 - loss: 2.2850 - val_accuracy: 0.1905 - val_loss: 2.2743 - learning_rate: 1.0000e-04
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1364 - loss: 2.2766
# Epoch 6: val_loss improved from 2.27433 to 2.26884, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 76s 121ms/step - accuracy: 0.1364 - loss: 2.2766 - val_accuracy: 0.2145 - val_loss: 2.2688 - learning_rate: 1.0000e-04
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1420 - loss: 2.2696
# Epoch 7: val_loss improved from 2.26884 to 2.26422, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 76s 121ms/step - accuracy: 0.1420 - loss: 2.2696 - val_accuracy: 0.2150 - val_loss: 2.2642 - learning_rate: 1.0000e-04
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.1455 - loss: 2.2642
# Epoch 8: val_loss improved from 2.26422 to 2.26012, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 120ms/step - accuracy: 0.1455 - loss: 2.2642 - val_accuracy: 0.2150 - val_loss: 2.2601 - learning_rate: 1.0000e-04
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1544 - loss: 2.2594
# Epoch 9: val_loss improved from 2.26012 to 2.25543, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 121ms/step - accuracy: 0.1544 - loss: 2.2594 - val_accuracy: 0.2175 - val_loss: 2.2554 - learning_rate: 1.0000e-04
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1574 - loss: 2.2552
# Epoch 10: val_loss improved from 2.25543 to 2.25192, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 76s 121ms/step - accuracy: 0.1574 - loss: 2.2552 - val_accuracy: 0.2310 - val_loss: 2.2519 - learning_rate: 1.0000e-04
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1565 - loss: 2.2521
# Epoch 11: val_loss improved from 2.25192 to 2.24841, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1565 - loss: 2.2521 - val_accuracy: 0.2280 - val_loss: 2.2484 - learning_rate: 1.0000e-04
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1614 - loss: 2.2494
# Epoch 12: val_loss improved from 2.24841 to 2.24489, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1614 - loss: 2.2494 - val_accuracy: 0.2270 - val_loss: 2.2449 - learning_rate: 1.0000e-04
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1646 - loss: 2.2436
# Epoch 13: val_loss improved from 2.24489 to 2.24061, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1646 - loss: 2.2436 - val_accuracy: 0.2320 - val_loss: 2.2406 - learning_rate: 1.0000e-04
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1678 - loss: 2.2411
# Epoch 14: val_loss improved from 2.24061 to 2.23796, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1678 - loss: 2.2411 - val_accuracy: 0.2275 - val_loss: 2.2380 - learning_rate: 1.0000e-04
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.1725 - loss: 2.2375
# Epoch 15: val_loss improved from 2.23796 to 2.23433, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 120ms/step - accuracy: 0.1725 - loss: 2.2375 - val_accuracy: 0.2195 - val_loss: 2.2343 - learning_rate: 1.0000e-04
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.1732 - loss: 2.2360
# Epoch 16: val_loss improved from 2.23433 to 2.23226, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1731 - loss: 2.2360 - val_accuracy: 0.2165 - val_loss: 2.2323 - learning_rate: 1.0000e-04
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1750 - loss: 2.2328
# Epoch 17: val_loss improved from 2.23226 to 2.22867, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1750 - loss: 2.2328 - val_accuracy: 0.2325 - val_loss: 2.2287 - learning_rate: 1.0000e-04
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1784 - loss: 2.2298
# Epoch 18: val_loss improved from 2.22867 to 2.22471, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1784 - loss: 2.2298 - val_accuracy: 0.2290 - val_loss: 2.2247 - learning_rate: 1.0000e-04
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1783 - loss: 2.2267
# Epoch 19: val_loss improved from 2.22471 to 2.22191, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1783 - loss: 2.2267 - val_accuracy: 0.2260 - val_loss: 2.2219 - learning_rate: 1.0000e-04
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1785 - loss: 2.2260
# Epoch 20: val_loss improved from 2.22191 to 2.22058, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1785 - loss: 2.2260 - val_accuracy: 0.2275 - val_loss: 2.2206 - learning_rate: 1.0000e-04
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1783 - loss: 2.2211
# Epoch 21: val_loss improved from 2.22058 to 2.21757, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1783 - loss: 2.2211 - val_accuracy: 0.2315 - val_loss: 2.2176 - learning_rate: 1.0000e-04
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1822 - loss: 2.2221
# Epoch 22: val_loss improved from 2.21757 to 2.21467, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1822 - loss: 2.2221 - val_accuracy: 0.2385 - val_loss: 2.2147 - learning_rate: 1.0000e-04
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1857 - loss: 2.2180
# Epoch 23: val_loss improved from 2.21467 to 2.21134, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1857 - loss: 2.2180 - val_accuracy: 0.2315 - val_loss: 2.2113 - learning_rate: 1.0000e-04
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1882 - loss: 2.2163
# Epoch 24: val_loss improved from 2.21134 to 2.20945, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1881 - loss: 2.2162 - val_accuracy: 0.2405 - val_loss: 2.2094 - learning_rate: 1.0000e-04
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1895 - loss: 2.2160
# Epoch 25: val_loss improved from 2.20945 to 2.20721, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1895 - loss: 2.2160 - val_accuracy: 0.2445 - val_loss: 2.2072 - learning_rate: 1.0000e-04
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1887 - loss: 2.2128
# Epoch 26: val_loss improved from 2.20721 to 2.20468, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1887 - loss: 2.2128 - val_accuracy: 0.2450 - val_loss: 2.2047 - learning_rate: 1.0000e-04
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1860 - loss: 2.2115
# Epoch 27: val_loss improved from 2.20468 to 2.20274, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1860 - loss: 2.2115 - val_accuracy: 0.2445 - val_loss: 2.2027 - learning_rate: 1.0000e-04
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1888 - loss: 2.2090
# Epoch 28: val_loss improved from 2.20274 to 2.20086, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1888 - loss: 2.2090 - val_accuracy: 0.2375 - val_loss: 2.2009 - learning_rate: 1.0000e-04
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1919 - loss: 2.2052
# Epoch 29: val_loss improved from 2.20086 to 2.19851, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1919 - loss: 2.2052 - val_accuracy: 0.2385 - val_loss: 2.1985 - learning_rate: 1.0000e-04
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1971 - loss: 2.2037
# Epoch 30: val_loss improved from 2.19851 to 2.19539, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1971 - loss: 2.2037 - val_accuracy: 0.2490 - val_loss: 2.1954 - learning_rate: 1.0000e-04
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1968 - loss: 2.2051
# Epoch 31: val_loss improved from 2.19539 to 2.19363, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1968 - loss: 2.2051 - val_accuracy: 0.2400 - val_loss: 2.1936 - learning_rate: 1.0000e-04
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1998 - loss: 2.2006
# Epoch 32: val_loss improved from 2.19363 to 2.19151, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1998 - loss: 2.2006 - val_accuracy: 0.2390 - val_loss: 2.1915 - learning_rate: 1.0000e-04
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1929 - loss: 2.2012
# Epoch 33: val_loss improved from 2.19151 to 2.18922, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1929 - loss: 2.2012 - val_accuracy: 0.2480 - val_loss: 2.1892 - learning_rate: 1.0000e-04
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1982 - loss: 2.1989
# Epoch 34: val_loss improved from 2.18922 to 2.18703, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1982 - loss: 2.1989 - val_accuracy: 0.2495 - val_loss: 2.1870 - learning_rate: 1.0000e-04
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.1961 - loss: 2.1980
# Epoch 35: val_loss improved from 2.18703 to 2.18562, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.1961 - loss: 2.1980 - val_accuracy: 0.2460 - val_loss: 2.1856 - learning_rate: 1.0000e-04
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1988 - loss: 2.1946
# Epoch 36: val_loss improved from 2.18562 to 2.18296, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1988 - loss: 2.1946 - val_accuracy: 0.2475 - val_loss: 2.1830 - learning_rate: 1.0000e-04
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2004 - loss: 2.1921
# Epoch 37: val_loss improved from 2.18296 to 2.18182, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.2004 - loss: 2.1921 - val_accuracy: 0.2510 - val_loss: 2.1818 - learning_rate: 1.0000e-04
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1999 - loss: 2.1961
# Epoch 38: val_loss improved from 2.18182 to 2.17944, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1999 - loss: 2.1961 - val_accuracy: 0.2540 - val_loss: 2.1794 - learning_rate: 1.0000e-04
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1999 - loss: 2.1910
# Epoch 39: val_loss improved from 2.17944 to 2.17801, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.1999 - loss: 2.1910 - val_accuracy: 0.2485 - val_loss: 2.1780 - learning_rate: 1.0000e-04
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1986 - loss: 2.1920
# Epoch 40: val_loss improved from 2.17801 to 2.17634, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.1986 - loss: 2.1920 - val_accuracy: 0.2505 - val_loss: 2.1763 - learning_rate: 1.0000e-04
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2038 - loss: 2.1901
# Epoch 41: val_loss improved from 2.17634 to 2.17503, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.2038 - loss: 2.1901 - val_accuracy: 0.2585 - val_loss: 2.1750 - learning_rate: 1.0000e-04
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2034 - loss: 2.1873
# Epoch 42: val_loss improved from 2.17503 to 2.17270, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.2034 - loss: 2.1873 - val_accuracy: 0.2510 - val_loss: 2.1727 - learning_rate: 1.0000e-04
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2041 - loss: 2.1854
# Epoch 43: val_loss improved from 2.17270 to 2.17037, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.2041 - loss: 2.1854 - val_accuracy: 0.2575 - val_loss: 2.1704 - learning_rate: 1.0000e-04
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2026 - loss: 2.1850
# Epoch 44: val_loss improved from 2.17037 to 2.16929, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.2026 - loss: 2.1850 - val_accuracy: 0.2575 - val_loss: 2.1693 - learning_rate: 1.0000e-04
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2068 - loss: 2.1865
# Epoch 45: val_loss improved from 2.16929 to 2.16697, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.2068 - loss: 2.1865 - val_accuracy: 0.2510 - val_loss: 2.1670 - learning_rate: 1.0000e-04
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2042 - loss: 2.1835
# Epoch 46: val_loss improved from 2.16697 to 2.16649, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.2042 - loss: 2.1835 - val_accuracy: 0.2560 - val_loss: 2.1665 - learning_rate: 1.0000e-04
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2062 - loss: 2.1812
# Epoch 47: val_loss improved from 2.16649 to 2.16395, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.2062 - loss: 2.1812 - val_accuracy: 0.2630 - val_loss: 2.1639 - learning_rate: 1.0000e-04
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2042 - loss: 2.1812
# Epoch 48: val_loss improved from 2.16395 to 2.16285, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.2042 - loss: 2.1811 - val_accuracy: 0.2570 - val_loss: 2.1629 - learning_rate: 1.0000e-04
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2082 - loss: 2.1811
# Epoch 49: val_loss improved from 2.16285 to 2.16034, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2082 - loss: 2.1811 - val_accuracy: 0.2700 - val_loss: 2.1603 - learning_rate: 1.0000e-04
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2102 - loss: 2.1794
# Epoch 50: val_loss improved from 2.16034 to 2.15923, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.2102 - loss: 2.1794 - val_accuracy: 0.2590 - val_loss: 2.1592 - learning_rate: 1.0000e-04
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2041 - loss: 2.1774
# Epoch 51: val_loss improved from 2.15923 to 2.15794, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2041 - loss: 2.1774 - val_accuracy: 0.2625 - val_loss: 2.1579 - learning_rate: 1.0000e-04
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2142 - loss: 2.1757
# Epoch 52: val_loss improved from 2.15794 to 2.15706, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2142 - loss: 2.1757 - val_accuracy: 0.2620 - val_loss: 2.1571 - learning_rate: 1.0000e-04
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2042 - loss: 2.1786
# Epoch 53: val_loss improved from 2.15706 to 2.15530, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2042 - loss: 2.1786 - val_accuracy: 0.2750 - val_loss: 2.1553 - learning_rate: 1.0000e-04
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2113 - loss: 2.1737
# Epoch 54: val_loss improved from 2.15530 to 2.15367, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2113 - loss: 2.1737 - val_accuracy: 0.2560 - val_loss: 2.1537 - learning_rate: 1.0000e-04
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2096 - loss: 2.1762
# Epoch 55: val_loss improved from 2.15367 to 2.15249, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2096 - loss: 2.1762 - val_accuracy: 0.2660 - val_loss: 2.1525 - learning_rate: 1.0000e-04
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2129 - loss: 2.1716
# Epoch 56: val_loss improved from 2.15249 to 2.15000, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2129 - loss: 2.1716 - val_accuracy: 0.2630 - val_loss: 2.1500 - learning_rate: 1.0000e-04
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2102 - loss: 2.1698
# Epoch 57: val_loss improved from 2.15000 to 2.14860, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2102 - loss: 2.1698 - val_accuracy: 0.2720 - val_loss: 2.1486 - learning_rate: 1.0000e-04
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2095 - loss: 2.1700
# Epoch 58: val_loss did not improve from 2.14860
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 123ms/step - accuracy: 0.2095 - loss: 2.1700 - val_accuracy: 0.2675 - val_loss: 2.1488 - learning_rate: 1.0000e-04
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2127 - loss: 2.1710
# Epoch 59: val_loss improved from 2.14860 to 2.14717, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2127 - loss: 2.1710 - val_accuracy: 0.2735 - val_loss: 2.1472 - learning_rate: 1.0000e-04
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2089 - loss: 2.1715
# Epoch 60: val_loss improved from 2.14717 to 2.14490, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2089 - loss: 2.1715 - val_accuracy: 0.2665 - val_loss: 2.1449 - learning_rate: 1.0000e-04
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2096 - loss: 2.1690
# Epoch 61: val_loss improved from 2.14490 to 2.14427, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2096 - loss: 2.1690 - val_accuracy: 0.2655 - val_loss: 2.1443 - learning_rate: 1.0000e-04
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2152 - loss: 2.1685
# Epoch 62: val_loss improved from 2.14427 to 2.14226, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2152 - loss: 2.1685 - val_accuracy: 0.2690 - val_loss: 2.1423 - learning_rate: 1.0000e-04
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2167 - loss: 2.1658
# Epoch 63: val_loss improved from 2.14226 to 2.14167, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2166 - loss: 2.1658 - val_accuracy: 0.2825 - val_loss: 2.1417 - learning_rate: 1.0000e-04
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2178 - loss: 2.1689
# Epoch 64: val_loss improved from 2.14167 to 2.14018, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2178 - loss: 2.1689 - val_accuracy: 0.2690 - val_loss: 2.1402 - learning_rate: 1.0000e-04
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2105 - loss: 2.1669
# Epoch 65: val_loss improved from 2.14018 to 2.13813, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2105 - loss: 2.1669 - val_accuracy: 0.2685 - val_loss: 2.1381 - learning_rate: 1.0000e-04
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2100 - loss: 2.1651
# Epoch 66: val_loss improved from 2.13813 to 2.13729, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2100 - loss: 2.1651 - val_accuracy: 0.2735 - val_loss: 2.1373 - learning_rate: 1.0000e-04
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2155 - loss: 2.1629
# Epoch 67: val_loss improved from 2.13729 to 2.13593, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2155 - loss: 2.1629 - val_accuracy: 0.2800 - val_loss: 2.1359 - learning_rate: 1.0000e-04
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2147 - loss: 2.1663
# Epoch 68: val_loss improved from 2.13593 to 2.13536, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2147 - loss: 2.1663 - val_accuracy: 0.2715 - val_loss: 2.1354 - learning_rate: 1.0000e-04
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2147 - loss: 2.1646
# Epoch 69: val_loss improved from 2.13536 to 2.13394, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2147 - loss: 2.1646 - val_accuracy: 0.2765 - val_loss: 2.1339 - learning_rate: 1.0000e-04
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2160 - loss: 2.1617
# Epoch 70: val_loss improved from 2.13394 to 2.13252, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2160 - loss: 2.1617 - val_accuracy: 0.2750 - val_loss: 2.1325 - learning_rate: 1.0000e-04
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2158 - loss: 2.1625
# Epoch 71: val_loss improved from 2.13252 to 2.13157, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2158 - loss: 2.1625 - val_accuracy: 0.2830 - val_loss: 2.1316 - learning_rate: 1.0000e-04
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2193 - loss: 2.1606
# Epoch 72: val_loss improved from 2.13157 to 2.13008, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 126ms/step - accuracy: 0.2193 - loss: 2.1606 - val_accuracy: 0.2830 - val_loss: 2.1301 - learning_rate: 1.0000e-04
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2135 - loss: 2.1607
# Epoch 73: val_loss improved from 2.13008 to 2.12909, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2135 - loss: 2.1607 - val_accuracy: 0.2805 - val_loss: 2.1291 - learning_rate: 1.0000e-04
# Epoch 74/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2174 - loss: 2.1569
# Epoch 74: val_loss improved from 2.12909 to 2.12774, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2174 - loss: 2.1569 - val_accuracy: 0.2820 - val_loss: 2.1277 - learning_rate: 1.0000e-04
# Epoch 75/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2197 - loss: 2.1587
# Epoch 75: val_loss improved from 2.12774 to 2.12661, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2197 - loss: 2.1587 - val_accuracy: 0.2825 - val_loss: 2.1266 - learning_rate: 1.0000e-04
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2187 - loss: 2.1589
# Epoch 76: val_loss improved from 2.12661 to 2.12519, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2187 - loss: 2.1589 - val_accuracy: 0.2835 - val_loss: 2.1252 - learning_rate: 1.0000e-04
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2157 - loss: 2.1568
# Epoch 77: val_loss improved from 2.12519 to 2.12339, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2157 - loss: 2.1568 - val_accuracy: 0.2845 - val_loss: 2.1234 - learning_rate: 1.0000e-04
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2179 - loss: 2.1533
# Epoch 78: val_loss improved from 2.12339 to 2.12298, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.2179 - loss: 2.1533 - val_accuracy: 0.2845 - val_loss: 2.1230 - learning_rate: 1.0000e-04
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2181 - loss: 2.1569
# Epoch 79: val_loss improved from 2.12298 to 2.12174, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2181 - loss: 2.1569 - val_accuracy: 0.2820 - val_loss: 2.1217 - learning_rate: 1.0000e-04
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2212 - loss: 2.1538
# Epoch 80: val_loss improved from 2.12174 to 2.12136, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2212 - loss: 2.1538 - val_accuracy: 0.2880 - val_loss: 2.1214 - learning_rate: 1.0000e-04
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2188 - loss: 2.1529
# Epoch 81: val_loss improved from 2.12136 to 2.11992, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2188 - loss: 2.1529 - val_accuracy: 0.2830 - val_loss: 2.1199 - learning_rate: 1.0000e-04
# Epoch 82/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2197 - loss: 2.1531
# Epoch 82: val_loss improved from 2.11992 to 2.11850, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2197 - loss: 2.1531 - val_accuracy: 0.2885 - val_loss: 2.1185 - learning_rate: 1.0000e-04
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2155 - loss: 2.1520
# Epoch 83: val_loss improved from 2.11850 to 2.11721, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2154 - loss: 2.1520 - val_accuracy: 0.2870 - val_loss: 2.1172 - learning_rate: 1.0000e-04
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2164 - loss: 2.1564
# Epoch 84: val_loss improved from 2.11721 to 2.11597, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2164 - loss: 2.1564 - val_accuracy: 0.2855 - val_loss: 2.1160 - learning_rate: 1.0000e-04
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2139 - loss: 2.1562
# Epoch 85: val_loss improved from 2.11597 to 2.11474, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2139 - loss: 2.1562 - val_accuracy: 0.2860 - val_loss: 2.1147 - learning_rate: 1.0000e-04
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2187 - loss: 2.1494
# Epoch 86: val_loss improved from 2.11474 to 2.11453, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2187 - loss: 2.1494 - val_accuracy: 0.2855 - val_loss: 2.1145 - learning_rate: 1.0000e-04
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2170 - loss: 2.1516
# Epoch 87: val_loss improved from 2.11453 to 2.11280, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2170 - loss: 2.1516 - val_accuracy: 0.2890 - val_loss: 2.1128 - learning_rate: 1.0000e-04
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2211 - loss: 2.1500
# Epoch 88: val_loss did not improve from 2.11280
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.2211 - loss: 2.1500 - val_accuracy: 0.2875 - val_loss: 2.1132 - learning_rate: 1.0000e-04
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2202 - loss: 2.1500
# Epoch 89: val_loss improved from 2.11280 to 2.11134, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2202 - loss: 2.1500 - val_accuracy: 0.2835 - val_loss: 2.1113 - learning_rate: 1.0000e-04
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2211 - loss: 2.1492
# Epoch 90: val_loss improved from 2.11134 to 2.11070, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2211 - loss: 2.1492 - val_accuracy: 0.2860 - val_loss: 2.1107 - learning_rate: 1.0000e-04
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2218 - loss: 2.1482
# Epoch 91: val_loss improved from 2.11070 to 2.10900, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2217 - loss: 2.1482 - val_accuracy: 0.2935 - val_loss: 2.1090 - learning_rate: 1.0000e-04
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2246 - loss: 2.1471
# Epoch 92: val_loss improved from 2.10900 to 2.10880, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2246 - loss: 2.1471 - val_accuracy: 0.2815 - val_loss: 2.1088 - learning_rate: 1.0000e-04
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2186 - loss: 2.1490
# Epoch 93: val_loss improved from 2.10880 to 2.10819, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2186 - loss: 2.1490 - val_accuracy: 0.2900 - val_loss: 2.1082 - learning_rate: 1.0000e-04
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2221 - loss: 2.1458
# Epoch 94: val_loss improved from 2.10819 to 2.10612, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2221 - loss: 2.1458 - val_accuracy: 0.2860 - val_loss: 2.1061 - learning_rate: 1.0000e-04
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2208 - loss: 2.1487
# Epoch 95: val_loss improved from 2.10612 to 2.10578, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2208 - loss: 2.1487 - val_accuracy: 0.2880 - val_loss: 2.1058 - learning_rate: 1.0000e-04
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2207 - loss: 2.1468
# Epoch 96: val_loss improved from 2.10578 to 2.10434, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2207 - loss: 2.1468 - val_accuracy: 0.2845 - val_loss: 2.1043 - learning_rate: 1.0000e-04
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2198 - loss: 2.1482
# Epoch 97: val_loss improved from 2.10434 to 2.10290, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2198 - loss: 2.1482 - val_accuracy: 0.2910 - val_loss: 2.1029 - learning_rate: 1.0000e-04
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.2223 - loss: 2.1463
# Epoch 98: val_loss improved from 2.10290 to 2.10278, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 127ms/step - accuracy: 0.2223 - loss: 2.1463 - val_accuracy: 0.2940 - val_loss: 2.1028 - learning_rate: 1.0000e-04
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2257 - loss: 2.1427
# Epoch 99: val_loss improved from 2.10278 to 2.10184, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.2257 - loss: 2.1427 - val_accuracy: 0.2920 - val_loss: 2.1018 - learning_rate: 1.0000e-04
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.2230 - loss: 2.1430
# Epoch 100: val_loss improved from 2.10184 to 2.10096, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 127ms/step - accuracy: 0.2230 - loss: 2.1430 - val_accuracy: 0.2925 - val_loss: 2.1010 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 100.

# %%
loss1, accuracy1 = model.evaluate(test_dataset)
print('Test loss :', loss1)
print('Test accuracy :', accuracy1)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.2992 - loss: 2.0559
# Test loss : 2.0586729049682617
# Test accuracy : 0.2985000014305115

# %%
loss1_res, accuracy1_res = model_resnet.evaluate(test_dataset)
print('Test loss :', loss1_res)
print('Test accuracy :', accuracy1_res)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.2743 - loss: 2.1043
# Test loss : 2.1070783138275146
# Test accuracy : 0.27399998903274536

# %%
history_df = pd.DataFrame(history.history)

# %%
history_df_resnet = pd.DataFrame(history_resnet.history)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history_df['accuracy'], label='Training Accuracy')
plt.plot(history_df['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_df['loss'], label='Training Loss')
plt.plot(history_df['val_loss'], label='Validation Loss')
plt.title("Loss Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history_df_resnet['accuracy'], label='Training Accuracy')
plt.plot(history_df_resnet['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_df_resnet['loss'], label='Training Loss')
plt.plot(history_df_resnet['val_loss'], label='Validation Loss')
plt.title("Loss Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix

y_true = []
y_pred = []
for images, labels in test_dataset:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

cm = confusion_matrix(y_true, y_pred)

# %%
# Plot
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## 5. Fine-tune top few layers of the base model after initial training

# %%
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  154

# %%
base_model.trainable = True

# %%
base_model_resnet.trainable = True

# %%
fine_tune_at = 100

for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

# %%
fine_tune_at = 100

for layer in base_model_resnet.layers[:fine_tune_at]:
  layer.trainable = False

# %%
len(model.trainable_variables)
# Out:
# 56

# %%
len(model_resnet.trainable_variables)
# Out:
# 92

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(learning_rate=base_learning_rate/10),
              metrics=["accuracy"])

# %%
model_resnet.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(learning_rate=base_learning_rate/10),
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_128            │ (None, 4, 4, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        12,810 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,270,794 (8.66 MB)
#  Trainable params: 1,874,250 (7.15 MB)
#  Non-trainable params: 396,544 (1.51 MB)

# %%
model_resnet.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 128, 128,  │          0 │ input_layer_5[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 128, 128)  │          0 │ sequential[2][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_4          │ (None, 128, 128)  │          0 │ sequential[2][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_5          │ (None, 128, 128)  │          0 │ sequential[2][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_1 (Stack)     │ (None, 128, 128,  │          0 │ get_item_3[0][0], │
# │                     │ 3)                │            │ get_item_4[0][0], │
# │                     │                   │            │ get_item_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 128,  │          0 │ stack_1[0][0]     │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 4, 4,      │ 23,587,712 │ add_1[0][0]       │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[1][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 10)        │     20,490 │ dropout[2][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,608,202 (90.06 MB)
#  Trainable params: 19,473,418 (74.29 MB)
#  Non-trainable params: 4,134,784 (15.77 MB)

# %%
fine_tune_epochs = 200
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=len(history.epoch),
                         validation_data=validation_dataset,
                         callbacks=[reduce_lr, checkpoint, early_stop])
# Out:
# Epoch 101/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1967 - loss: 4.8832
# Epoch 101: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 221s 337ms/step - accuracy: 0.1968 - loss: 4.8808 - val_accuracy: 0.0930 - val_loss: 11.2804 - learning_rate: 1.0000e-05
# Epoch 102/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.2708 - loss: 2.1930
# Epoch 102: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.2708 - loss: 2.1928 - val_accuracy: 0.1010 - val_loss: 16.8208 - learning_rate: 1.0000e-05
# Epoch 103/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.3209 - loss: 1.9178
# Epoch 103: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 207s 332ms/step - accuracy: 0.3210 - loss: 1.9177 - val_accuracy: 0.1010 - val_loss: 17.2895 - learning_rate: 1.0000e-05
# Epoch 104/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.3516 - loss: 1.8221
# Epoch 104: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 104: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 212s 340ms/step - accuracy: 0.3516 - loss: 1.8220 - val_accuracy: 0.1010 - val_loss: 15.2842 - learning_rate: 1.0000e-05
# Epoch 105/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.3689 - loss: 1.7640
# Epoch 105: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 217s 346ms/step - accuracy: 0.3689 - loss: 1.7640 - val_accuracy: 0.1050 - val_loss: 8.3191 - learning_rate: 5.0000e-06
# Epoch 106/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.3830 - loss: 1.7357
# Epoch 106: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 212s 339ms/step - accuracy: 0.3830 - loss: 1.7357 - val_accuracy: 0.1180 - val_loss: 3.8157 - learning_rate: 5.0000e-06
# Epoch 107/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.3844 - loss: 1.7180
# Epoch 107: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 214s 343ms/step - accuracy: 0.3844 - loss: 1.7180 - val_accuracy: 0.1185 - val_loss: 3.7676 - learning_rate: 5.0000e-06
# Epoch 108/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.3958 - loss: 1.6983
# Epoch 108: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 337ms/step - accuracy: 0.3958 - loss: 1.6983 - val_accuracy: 0.1725 - val_loss: 3.3691 - learning_rate: 5.0000e-06
# Epoch 109/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4029 - loss: 1.6810
# Epoch 109: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4029 - loss: 1.6810 - val_accuracy: 0.1935 - val_loss: 2.7239 - learning_rate: 5.0000e-06
# Epoch 110/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4082 - loss: 1.6673
# Epoch 110: val_loss did not improve from 2.05849
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4082 - loss: 1.6673 - val_accuracy: 0.2680 - val_loss: 2.1376 - learning_rate: 5.0000e-06
# Epoch 111/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4105 - loss: 1.6499
# Epoch 111: val_loss improved from 2.05849 to 1.84453, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 212s 339ms/step - accuracy: 0.4105 - loss: 1.6499 - val_accuracy: 0.3465 - val_loss: 1.8445 - learning_rate: 5.0000e-06
# Epoch 112/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.4198 - loss: 1.6343
# Epoch 112: val_loss improved from 1.84453 to 1.63945, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 213s 341ms/step - accuracy: 0.4198 - loss: 1.6343 - val_accuracy: 0.4320 - val_loss: 1.6395 - learning_rate: 5.0000e-06
# Epoch 113/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4273 - loss: 1.6203
# Epoch 113: val_loss improved from 1.63945 to 1.53606, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 213s 341ms/step - accuracy: 0.4273 - loss: 1.6203 - val_accuracy: 0.4570 - val_loss: 1.5361 - learning_rate: 5.0000e-06
# Epoch 114/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4217 - loss: 1.6183
# Epoch 114: val_loss did not improve from 1.53606
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4217 - loss: 1.6183 - val_accuracy: 0.4450 - val_loss: 1.6426 - learning_rate: 5.0000e-06
# Epoch 115/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4333 - loss: 1.6019
# Epoch 115: val_loss did not improve from 1.53606
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 337ms/step - accuracy: 0.4333 - loss: 1.6019 - val_accuracy: 0.4400 - val_loss: 1.5703 - learning_rate: 5.0000e-06
# Epoch 116/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4359 - loss: 1.5903
# Epoch 116: val_loss improved from 1.53606 to 1.51760, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 212s 339ms/step - accuracy: 0.4359 - loss: 1.5903 - val_accuracy: 0.4605 - val_loss: 1.5176 - learning_rate: 5.0000e-06
# Epoch 117/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.4386 - loss: 1.5757
# Epoch 117: val_loss did not improve from 1.51760
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 228s 364ms/step - accuracy: 0.4386 - loss: 1.5757 - val_accuracy: 0.4460 - val_loss: 1.5341 - learning_rate: 5.0000e-06
# Epoch 118/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.4379 - loss: 1.5742
# Epoch 118: val_loss improved from 1.51760 to 1.46623, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 296s 473ms/step - accuracy: 0.4379 - loss: 1.5741 - val_accuracy: 0.4740 - val_loss: 1.4662 - learning_rate: 5.0000e-06
# Epoch 119/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.4424 - loss: 1.5667
# Epoch 119: val_loss did not improve from 1.46623
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 268s 428ms/step - accuracy: 0.4424 - loss: 1.5667 - val_accuracy: 0.4355 - val_loss: 1.6831 - learning_rate: 5.0000e-06
# Epoch 120/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.4495 - loss: 1.5545
# Epoch 120: val_loss did not improve from 1.46623
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 276s 441ms/step - accuracy: 0.4495 - loss: 1.5545 - val_accuracy: 0.4780 - val_loss: 1.5219 - learning_rate: 5.0000e-06
# Epoch 121/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.4512 - loss: 1.5500
# Epoch 121: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 121: val_loss did not improve from 1.46623
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 223s 357ms/step - accuracy: 0.4512 - loss: 1.5500 - val_accuracy: 0.4605 - val_loss: 1.5055 - learning_rate: 5.0000e-06
# Epoch 122/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.4539 - loss: 1.5313
# Epoch 122: val_loss improved from 1.46623 to 1.44286, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 223s 357ms/step - accuracy: 0.4539 - loss: 1.5313 - val_accuracy: 0.4795 - val_loss: 1.4429 - learning_rate: 2.5000e-06
# Epoch 123/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.4538 - loss: 1.5306
# Epoch 123: val_loss did not improve from 1.44286
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 224s 358ms/step - accuracy: 0.4538 - loss: 1.5306 - val_accuracy: 0.4910 - val_loss: 1.4797 - learning_rate: 2.5000e-06
# Epoch 124/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.4566 - loss: 1.5261
# Epoch 124: val_loss did not improve from 1.44286
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 245s 392ms/step - accuracy: 0.4566 - loss: 1.5260 - val_accuracy: 0.4990 - val_loss: 1.4576 - learning_rate: 2.5000e-06
# Epoch 125/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.4613 - loss: 1.5200
# Epoch 125: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 125: val_loss did not improve from 1.44286
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 275s 440ms/step - accuracy: 0.4613 - loss: 1.5200 - val_accuracy: 0.4750 - val_loss: 1.4856 - learning_rate: 2.5000e-06
# Epoch 126/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4644 - loss: 1.5063
# Epoch 126: val_loss did not improve from 1.44286
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 212s 339ms/step - accuracy: 0.4644 - loss: 1.5063 - val_accuracy: 0.4720 - val_loss: 1.4890 - learning_rate: 1.2500e-06
# Epoch 127/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4672 - loss: 1.5029
# Epoch 127: val_loss improved from 1.44286 to 1.40285, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4672 - loss: 1.5029 - val_accuracy: 0.5060 - val_loss: 1.4028 - learning_rate: 1.2500e-06
# Epoch 128/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4645 - loss: 1.5044
# Epoch 128: val_loss did not improve from 1.40285
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4645 - loss: 1.5044 - val_accuracy: 0.5035 - val_loss: 1.4249 - learning_rate: 1.2500e-06
# Epoch 129/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4650 - loss: 1.5033
# Epoch 129: val_loss improved from 1.40285 to 1.39092, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 213s 340ms/step - accuracy: 0.4650 - loss: 1.5033 - val_accuracy: 0.5110 - val_loss: 1.3909 - learning_rate: 1.2500e-06
# Epoch 130/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4622 - loss: 1.5040
# Epoch 130: val_loss improved from 1.39092 to 1.36214, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 212s 340ms/step - accuracy: 0.4622 - loss: 1.5040 - val_accuracy: 0.5225 - val_loss: 1.3621 - learning_rate: 1.2500e-06
# Epoch 131/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4645 - loss: 1.5032
# Epoch 131: val_loss did not improve from 1.36214
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4645 - loss: 1.5032 - val_accuracy: 0.5295 - val_loss: 1.3731 - learning_rate: 1.2500e-06
# Epoch 132/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4645 - loss: 1.5056
# Epoch 132: val_loss did not improve from 1.36214
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 208s 333ms/step - accuracy: 0.4645 - loss: 1.5056 - val_accuracy: 0.5205 - val_loss: 1.3656 - learning_rate: 1.2500e-06
# Epoch 133/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4679 - loss: 1.4943
# Epoch 133: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 133: val_loss improved from 1.36214 to 1.36214, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4679 - loss: 1.4943 - val_accuracy: 0.5190 - val_loss: 1.3621 - learning_rate: 1.2500e-06
# Epoch 134/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4693 - loss: 1.4894
# Epoch 134: val_loss did not improve from 1.36214
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4693 - loss: 1.4894 - val_accuracy: 0.5180 - val_loss: 1.3678 - learning_rate: 1.0000e-06
# Epoch 135/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.4735 - loss: 1.4878
# Epoch 135: val_loss did not improve from 1.36214
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 214s 342ms/step - accuracy: 0.4735 - loss: 1.4878 - val_accuracy: 0.5140 - val_loss: 1.3864 - learning_rate: 1.0000e-06
# Epoch 136/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.4666 - loss: 1.4933
# Epoch 136: val_loss did not improve from 1.36214
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 213s 341ms/step - accuracy: 0.4666 - loss: 1.4933 - val_accuracy: 0.5140 - val_loss: 1.3815 - learning_rate: 1.0000e-06
# Epoch 137/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4674 - loss: 1.4870
# Epoch 137: val_loss did not improve from 1.36214
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4674 - loss: 1.4870 - val_accuracy: 0.5120 - val_loss: 1.3677 - learning_rate: 1.0000e-06
# Epoch 138/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4710 - loss: 1.4893
# Epoch 138: val_loss did not improve from 1.36214
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4710 - loss: 1.4892 - val_accuracy: 0.5255 - val_loss: 1.3641 - learning_rate: 1.0000e-06
# Epoch 139/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4753 - loss: 1.4825
# Epoch 139: val_loss improved from 1.36214 to 1.35276, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4753 - loss: 1.4825 - val_accuracy: 0.5245 - val_loss: 1.3528 - learning_rate: 1.0000e-06
# Epoch 140/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4748 - loss: 1.4844
# Epoch 140: val_loss did not improve from 1.35276
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4748 - loss: 1.4844 - val_accuracy: 0.5260 - val_loss: 1.3559 - learning_rate: 1.0000e-06
# Epoch 141/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4727 - loss: 1.4785
# Epoch 141: val_loss did not improve from 1.35276
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4727 - loss: 1.4784 - val_accuracy: 0.5310 - val_loss: 1.3599 - learning_rate: 1.0000e-06
# Epoch 142/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4738 - loss: 1.4772
# Epoch 142: val_loss did not improve from 1.35276
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4738 - loss: 1.4771 - val_accuracy: 0.5190 - val_loss: 1.3898 - learning_rate: 1.0000e-06
# Epoch 143/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4711 - loss: 1.4847
# Epoch 143: val_loss improved from 1.35276 to 1.35259, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4711 - loss: 1.4846 - val_accuracy: 0.5250 - val_loss: 1.3526 - learning_rate: 1.0000e-06
# Epoch 144/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4702 - loss: 1.4857
# Epoch 144: val_loss did not improve from 1.35259
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4702 - loss: 1.4857 - val_accuracy: 0.5170 - val_loss: 1.3659 - learning_rate: 1.0000e-06
# Epoch 145/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4751 - loss: 1.4747
# Epoch 145: val_loss did not improve from 1.35259
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 208s 334ms/step - accuracy: 0.4751 - loss: 1.4747 - val_accuracy: 0.5245 - val_loss: 1.3613 - learning_rate: 1.0000e-06
# Epoch 146/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4723 - loss: 1.4753
# Epoch 146: val_loss did not improve from 1.35259
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 337ms/step - accuracy: 0.4723 - loss: 1.4753 - val_accuracy: 0.5335 - val_loss: 1.3557 - learning_rate: 1.0000e-06
# Epoch 147/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4765 - loss: 1.4703
# Epoch 147: val_loss did not improve from 1.35259
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4765 - loss: 1.4703 - val_accuracy: 0.5325 - val_loss: 1.3609 - learning_rate: 1.0000e-06
# Epoch 148/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4751 - loss: 1.4794
# Epoch 148: val_loss improved from 1.35259 to 1.35197, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4751 - loss: 1.4794 - val_accuracy: 0.5285 - val_loss: 1.3520 - learning_rate: 1.0000e-06
# Epoch 149/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4749 - loss: 1.4763
# Epoch 149: val_loss improved from 1.35197 to 1.35071, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4750 - loss: 1.4763 - val_accuracy: 0.5200 - val_loss: 1.3507 - learning_rate: 1.0000e-06
# Epoch 150/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4806 - loss: 1.4678
# Epoch 150: val_loss did not improve from 1.35071
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4806 - loss: 1.4678 - val_accuracy: 0.5180 - val_loss: 1.3573 - learning_rate: 1.0000e-06
# Epoch 151/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4777 - loss: 1.4703
# Epoch 151: val_loss improved from 1.35071 to 1.34198, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4777 - loss: 1.4703 - val_accuracy: 0.5200 - val_loss: 1.3420 - learning_rate: 1.0000e-06
# Epoch 152/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4764 - loss: 1.4698
# Epoch 152: val_loss improved from 1.34198 to 1.34005, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 211s 337ms/step - accuracy: 0.4764 - loss: 1.4698 - val_accuracy: 0.5170 - val_loss: 1.3400 - learning_rate: 1.0000e-06
# Epoch 153/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4792 - loss: 1.4671
# Epoch 153: val_loss did not improve from 1.34005
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4792 - loss: 1.4671 - val_accuracy: 0.5290 - val_loss: 1.3521 - learning_rate: 1.0000e-06
# Epoch 154/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4835 - loss: 1.4561
# Epoch 154: val_loss did not improve from 1.34005
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 335ms/step - accuracy: 0.4835 - loss: 1.4561 - val_accuracy: 0.5275 - val_loss: 1.3506 - learning_rate: 1.0000e-06
# Epoch 155/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4802 - loss: 1.4599
# Epoch 155: val_loss did not improve from 1.34005
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4802 - loss: 1.4599 - val_accuracy: 0.5170 - val_loss: 1.3585 - learning_rate: 1.0000e-06
# Epoch 156/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4778 - loss: 1.4616
# Epoch 156: val_loss improved from 1.34005 to 1.33495, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 211s 338ms/step - accuracy: 0.4778 - loss: 1.4616 - val_accuracy: 0.5330 - val_loss: 1.3349 - learning_rate: 1.0000e-06
# Epoch 157/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4858 - loss: 1.4600
# Epoch 157: val_loss did not improve from 1.33495
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 337ms/step - accuracy: 0.4858 - loss: 1.4600 - val_accuracy: 0.5245 - val_loss: 1.3416 - learning_rate: 1.0000e-06
# Epoch 158/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4812 - loss: 1.4607
# Epoch 158: val_loss did not improve from 1.33495
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4812 - loss: 1.4607 - val_accuracy: 0.5250 - val_loss: 1.3424 - learning_rate: 1.0000e-06
# Epoch 159/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4858 - loss: 1.4544
# Epoch 159: val_loss improved from 1.33495 to 1.33283, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4858 - loss: 1.4544 - val_accuracy: 0.5305 - val_loss: 1.3328 - learning_rate: 1.0000e-06
# Epoch 160/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4839 - loss: 1.4549
# Epoch 160: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 335ms/step - accuracy: 0.4839 - loss: 1.4549 - val_accuracy: 0.5365 - val_loss: 1.3340 - learning_rate: 1.0000e-06
# Epoch 161/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4792 - loss: 1.4617
# Epoch 161: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4792 - loss: 1.4617 - val_accuracy: 0.5175 - val_loss: 1.3714 - learning_rate: 1.0000e-06
# Epoch 162/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4863 - loss: 1.4542
# Epoch 162: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4863 - loss: 1.4542 - val_accuracy: 0.5310 - val_loss: 1.3365 - learning_rate: 1.0000e-06
# Epoch 163/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4847 - loss: 1.4539
# Epoch 163: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 336ms/step - accuracy: 0.4847 - loss: 1.4539 - val_accuracy: 0.5325 - val_loss: 1.3361 - learning_rate: 1.0000e-06
# Epoch 164/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4787 - loss: 1.4589
# Epoch 164: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 337ms/step - accuracy: 0.4788 - loss: 1.4589 - val_accuracy: 0.5425 - val_loss: 1.3336 - learning_rate: 1.0000e-06
# Epoch 165/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4843 - loss: 1.4531
# Epoch 165: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 334ms/step - accuracy: 0.4843 - loss: 1.4530 - val_accuracy: 0.5265 - val_loss: 1.3551 - learning_rate: 1.0000e-06
# Epoch 166/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4870 - loss: 1.4401
# Epoch 166: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4870 - loss: 1.4401 - val_accuracy: 0.5390 - val_loss: 1.3347 - learning_rate: 1.0000e-06
# Epoch 167/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4800 - loss: 1.4550
# Epoch 167: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 337ms/step - accuracy: 0.4800 - loss: 1.4550 - val_accuracy: 0.5255 - val_loss: 1.3337 - learning_rate: 1.0000e-06
# Epoch 168/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4827 - loss: 1.4455
# Epoch 168: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4827 - loss: 1.4455 - val_accuracy: 0.5315 - val_loss: 1.3399 - learning_rate: 1.0000e-06
# Epoch 169/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4853 - loss: 1.4504
# Epoch 169: val_loss did not improve from 1.33283
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 335ms/step - accuracy: 0.4853 - loss: 1.4504 - val_accuracy: 0.5335 - val_loss: 1.3371 - learning_rate: 1.0000e-06
# Epoch 169: early stopping
# Restoring model weights from the end of the best epoch: 159.

# %%
fine_tune_epochs = 200
total_epochs =  initial_epochs + fine_tune_epochs

history_fine_resnet = model_resnet.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=len(history.epoch),
                         validation_data=validation_dataset,
                         callbacks=[reduce_lr, checkpoint, early_stop])
# Out:
# Epoch 101/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.2265 - loss: 3.4903
# Epoch 101: val_loss improved from 2.10096 to 1.88626, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 316s 481ms/step - accuracy: 0.2265 - loss: 3.4885 - val_accuracy: 0.3450 - val_loss: 1.8863 - learning_rate: 1.0000e-05
# Epoch 102/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.3492 - loss: 1.8183
# Epoch 102: val_loss improved from 1.88626 to 1.77818, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 301s 482ms/step - accuracy: 0.3492 - loss: 1.8182 - val_accuracy: 0.3815 - val_loss: 1.7782 - learning_rate: 1.0000e-05
# Epoch 103/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.3878 - loss: 1.7187
# Epoch 103: val_loss improved from 1.77818 to 1.58875, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 293s 469ms/step - accuracy: 0.3878 - loss: 1.7187 - val_accuracy: 0.4255 - val_loss: 1.5888 - learning_rate: 1.0000e-05
# Epoch 104/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.4113 - loss: 1.6585
# Epoch 104: val_loss improved from 1.58875 to 1.52188, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 295s 473ms/step - accuracy: 0.4113 - loss: 1.6584 - val_accuracy: 0.4705 - val_loss: 1.5219 - learning_rate: 1.0000e-05
# Epoch 105/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.4311 - loss: 1.6033
# Epoch 105: val_loss did not improve from 1.52188
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 294s 470ms/step - accuracy: 0.4311 - loss: 1.6033 - val_accuracy: 0.3470 - val_loss: 1.8708 - learning_rate: 1.0000e-05
# Epoch 106/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.4465 - loss: 1.5702
# Epoch 106: val_loss did not improve from 1.52188
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 293s 468ms/step - accuracy: 0.4465 - loss: 1.5702 - val_accuracy: 0.4225 - val_loss: 1.6642 - learning_rate: 1.0000e-05
# Epoch 107/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.4599 - loss: 1.5331
# Epoch 107: val_loss improved from 1.52188 to 1.50773, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 298s 477ms/step - accuracy: 0.4599 - loss: 1.5331 - val_accuracy: 0.4590 - val_loss: 1.5077 - learning_rate: 1.0000e-05
# Epoch 108/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.4689 - loss: 1.5005
# Epoch 108: val_loss did not improve from 1.50773
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 297s 476ms/step - accuracy: 0.4689 - loss: 1.5004 - val_accuracy: 0.4095 - val_loss: 1.7256 - learning_rate: 1.0000e-05
# Epoch 109/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.4783 - loss: 1.4776
# Epoch 109: val_loss did not improve from 1.50773
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 298s 476ms/step - accuracy: 0.4783 - loss: 1.4776 - val_accuracy: 0.4360 - val_loss: 1.5725 - learning_rate: 1.0000e-05
# Epoch 110/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.4864 - loss: 1.4475
# Epoch 110: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 110: val_loss did not improve from 1.50773
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 293s 469ms/step - accuracy: 0.4864 - loss: 1.4475 - val_accuracy: 0.4630 - val_loss: 1.5391 - learning_rate: 1.0000e-05
# Epoch 111/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.5046 - loss: 1.3924
# Epoch 111: val_loss improved from 1.50773 to 1.27182, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 297s 475ms/step - accuracy: 0.5046 - loss: 1.3924 - val_accuracy: 0.5475 - val_loss: 1.2718 - learning_rate: 5.0000e-06
# Epoch 112/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.5195 - loss: 1.3592
# Epoch 112: val_loss did not improve from 1.27182
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 293s 468ms/step - accuracy: 0.5195 - loss: 1.3592 - val_accuracy: 0.5120 - val_loss: 1.3845 - learning_rate: 5.0000e-06
# Epoch 113/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.5283 - loss: 1.3527
# Epoch 113: val_loss did not improve from 1.27182
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 294s 471ms/step - accuracy: 0.5283 - loss: 1.3527 - val_accuracy: 0.5140 - val_loss: 1.3641 - learning_rate: 5.0000e-06
# Epoch 114/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.5262 - loss: 1.3395
# Epoch 114: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 114: val_loss did not improve from 1.27182
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 294s 470ms/step - accuracy: 0.5262 - loss: 1.3394 - val_accuracy: 0.4725 - val_loss: 1.5460 - learning_rate: 5.0000e-06
# Epoch 115/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.5467 - loss: 1.2960
# Epoch 115: val_loss improved from 1.27182 to 1.19051, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 297s 474ms/step - accuracy: 0.5466 - loss: 1.2960 - val_accuracy: 0.5780 - val_loss: 1.1905 - learning_rate: 2.5000e-06
# Epoch 116/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.5433 - loss: 1.2843
# Epoch 116: val_loss did not improve from 1.19051
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 295s 472ms/step - accuracy: 0.5433 - loss: 1.2843 - val_accuracy: 0.5510 - val_loss: 1.3250 - learning_rate: 2.5000e-06
# Epoch 117/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.5531 - loss: 1.2750
# Epoch 117: val_loss did not improve from 1.19051
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 297s 475ms/step - accuracy: 0.5531 - loss: 1.2750 - val_accuracy: 0.5560 - val_loss: 1.2798 - learning_rate: 2.5000e-06
# Epoch 118/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.5527 - loss: 1.2639
# Epoch 118: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 118: val_loss did not improve from 1.19051
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 294s 471ms/step - accuracy: 0.5527 - loss: 1.2638 - val_accuracy: 0.5475 - val_loss: 1.2794 - learning_rate: 2.5000e-06
# Epoch 119/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.5619 - loss: 1.2459
# Epoch 119: val_loss improved from 1.19051 to 1.15595, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 299s 478ms/step - accuracy: 0.5619 - loss: 1.2458 - val_accuracy: 0.5905 - val_loss: 1.1560 - learning_rate: 1.2500e-06
# Epoch 120/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.5630 - loss: 1.2351
# Epoch 120: val_loss improved from 1.15595 to 1.15055, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 298s 476ms/step - accuracy: 0.5630 - loss: 1.2351 - val_accuracy: 0.5890 - val_loss: 1.1506 - learning_rate: 1.2500e-06
# Epoch 121/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.5636 - loss: 1.2364
# Epoch 121: val_loss improved from 1.15055 to 1.14235, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 296s 473ms/step - accuracy: 0.5636 - loss: 1.2364 - val_accuracy: 0.6075 - val_loss: 1.1423 - learning_rate: 1.2500e-06
# Epoch 122/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.5647 - loss: 1.2317
# Epoch 122: val_loss improved from 1.14235 to 1.13789, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 297s 475ms/step - accuracy: 0.5647 - loss: 1.2316 - val_accuracy: 0.6005 - val_loss: 1.1379 - learning_rate: 1.2500e-06
# Epoch 123/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.5703 - loss: 1.2251
# Epoch 123: val_loss did not improve from 1.13789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 294s 471ms/step - accuracy: 0.5703 - loss: 1.2251 - val_accuracy: 0.6000 - val_loss: 1.1466 - learning_rate: 1.2500e-06
# Epoch 124/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.5730 - loss: 1.2127
# Epoch 124: val_loss did not improve from 1.13789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 293s 469ms/step - accuracy: 0.5730 - loss: 1.2127 - val_accuracy: 0.5940 - val_loss: 1.1534 - learning_rate: 1.2500e-06
# Epoch 125/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.5743 - loss: 1.2156
# Epoch 125: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 125: val_loss did not improve from 1.13789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 293s 469ms/step - accuracy: 0.5743 - loss: 1.2155 - val_accuracy: 0.5920 - val_loss: 1.1581 - learning_rate: 1.2500e-06
# Epoch 126/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.5797 - loss: 1.2012
# Epoch 126: val_loss improved from 1.13789 to 1.12616, saving model to best_tuned_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 300s 480ms/step - accuracy: 0.5797 - loss: 1.2012 - val_accuracy: 0.6045 - val_loss: 1.1262 - learning_rate: 1.0000e-06
# Epoch 127/300
# 426/625 ━━━━━━━━━━━━━━━━━━━━ 1:34 476ms/step - accuracy: 0.5826 - loss: 1.1930

# %%
loss2, accuracy2 = model.evaluate(test_dataset)
print('Test loss :', loss2)
print('Test accuracy :', accuracy2)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.5195 - loss: 1.3636
# Test loss : 1.3733702898025513
# Test accuracy : 0.5133749842643738

# %%
loss2_resnet, accuracy2_resnet = model_resnet.evaluate(test_dataset)
print('Test loss :', loss2_resnet)
print('Test accuracy :', accuracy2_resnet)

# %%
history_fine_df = pd.DataFrame(history_fine.history)
history_fine_df.index += len(history_df)

# %%
history_fine_df_resnet = pd.DataFrame(history_fine_resnet.history)
history_fine_df_resnet.index += len(history_df_resnet)

# %%
history_full_df = pd.concat([history_df, history_fine_df])

# %%
history_full_df_resnet = pd.concat([history_df_resnet, history_fine_df_resnet])

# %%
finetune_start_epoch = len(history_df)

# %%
finetune_start_epoch_resnet = len(history_df_resnet)

# %%
plt.figure(figsize=(15, 5))

# --- Accuracy Plot ---
plt.subplot(1, 2, 1)
plt.plot(history_full_df['accuracy'], label='Training Accuracy')
plt.plot(history_full_df['val_accuracy'], label='Validation Accuracy')
plt.axvline(x=finetune_start_epoch, linestyle='--', color='green', label='Start Fine Tuning')
plt.title("Accuracy Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# --- Loss Plot ---
plt.subplot(1, 2, 2)
plt.plot(history_full_df['loss'], label='Training Loss')
plt.plot(history_full_df['val_loss'], label='Validation Loss')
plt.axvline(x=finetune_start_epoch, linestyle='--', color='green', label='Start Fine Tuning')
plt.title("Loss During Full Training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
plt.figure(figsize=(15, 5))

# --- Accuracy Plot ---
plt.subplot(1, 2, 1)
plt.plot(history_full_df_resnet['accuracy'], label='Training Accuracy')
plt.plot(history_full_df_resnet['val_accuracy'], label='Validation Accuracy')
plt.axvline(x=finetune_start_epoch_resnet, linestyle='--', color='green', label='Start Fine Tuning')
plt.title("Accuracy Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# --- Loss Plot ---
plt.subplot(1, 2, 2)
plt.plot(history_full_df_resnet['loss'], label='Training Loss')
plt.plot(history_full_df_resnet['val_loss'], label='Validation Loss')
plt.axvline(x=finetune_start_epoch_resnet, linestyle='--', color='green', label='Start Fine Tuning')
plt.title("Loss During Full Training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
y_true = []
y_pred = []
for images, labels in test_dataset:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

cm = confusion_matrix(y_true, y_pred)
# Out:
# 2025-07-05 01:24:09.757810: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Plot
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Print comparison side by side
print("\nComparison:")
print(f"{'Metric':<15}{'Base Model':<15}{'Fine Tuning'}")
print(f"{'-'*40}")
print(f"{'Loss':<15}{loss1:<15.4f}{loss2:.4f}")
print(f"{'Accuracy':<15}{accuracy1:<15.4f}{accuracy2:.4f}")
# Out:
# Comparison:
# Metric         Base Model     Fine Tuning
# ----------------------------------------
# Loss           2.0587         1.3734
# Accuracy       0.2985         0.5134

# %%
# Print comparison side by side
print("\nComparison: Resnet ")
print(f"{'Metric':<15}{'Base Model':<15}{'Fine Tuning'}")
print(f"{'-'*40}")
print(f"{'Loss':<15}{loss1_resnet:<15.4f}{loss2_resnet:.4f}")
print(f"{'Accuracy':<15}{accuracy1_resnet:<15.4f}{accuracy2_resnet:.4f}")

# %%
# Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
predicted_classes = np.argmax(predictions, axis=1)

print('Predictions:\n', predicted_classes)
print('Labels:\n', label_batch)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow((image_batch[i] * 255).astype("uint8"))
  true_label = class_names[label_batch[i]]
  predicted_label = class_names[predicted_classes[i]]
  plt.title(f"True: {true_label}\nPred: {predicted_label}", color="green" if true_label == predicted_label else "red")
  plt.axis("off")
# Out:
# Predictions:
#  [2 0 4 7 6 6 3 5 2 8 7 0 1 7 0 1 0 4 6 6 6 6 2 6 9 0 8 4 1 6 2 7 1 5 1 4 5
#  1 2 3 7 3 5 0 0 7 2 1 6 7 8 2 5 8 8 1 7 3 6 2 4 8 5 3]
# Labels:
#  [4 0 4 7 6 6 6 0 2 8 4 0 8 7 9 5 5 0 1 6 5 6 6 6 2 8 8 3 1 3 2 7 5 5 1 4 5
#  1 2 2 3 1 3 0 0 7 5 1 2 5 8 2 5 8 1 3 7 3 6 4 6 9 2 4]

# %%
# Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model_resnet.predict_on_batch(image_batch)
predicted_classes = np.argmax(predictions, axis=1)

print('Predictions:\n', predicted_classes)
print('Labels:\n', label_batch)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow((image_batch[i] * 255).astype("uint8"))
  true_label = class_names[label_batch[i]]
  predicted_label = class_names[predicted_classes[i]]
  plt.title(f"True: {true_label}\nPred: {predicted_label}", color="green" if true_label == predicted_label else "red")
  plt.axis("off")
